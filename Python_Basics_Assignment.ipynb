# %% [markdown]
# # Python Basics

# %% [markdown]
# 1. Explain the key features of Python that make it a popular choice for programming.
#    - Simple and easy to understand.
#    - widely used in the data industry.
#    - Versatility - can be used in development, Frontend, Backend, Data Analysis, Image Processing, Machine Learning etc.
#    - a lot of libraries.
#    - Strong community support.
#    - Supports Object Oriented Programming.
#
# 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#    - Keywords are predefined words that hold a special meaning and have specific purpose.
#    - they defined the syntax and structure of the Python Language.
#    - Example - if, else, int, class (Keywords)
#
#     - for example ->
#                name = 'khushi'
#
#                if name:
#                   return "Hello" + name
#                else:
#                   return "Who??"
#
#       - Here if,else,return are all predefined keywords which hold a special purpose to run a program.
#
# 3.  Compare and contrast mutable and immutable objects in Python with examples.
#     - Mutable Objects
#         - Objects/Container whose state or value can be changed after they are created are called as mutable objects or container.
#         - List is a type of mutable object.
#         - Example :  list = [1,2,3,4,5]
#            list[2]= 31
#            print(list)
#
#     - Immutable Objects
#          - Objects/Container whose state or value cannot be changed after they are created are called as immutable objects or container.
#          - String is a type of immutable object doesn't supports item assignment.
#          - Example :  str = 'khushi'
#                       str[1]= 'j'
#                       typeerror: 'str' object does not support item assignment
#
#
# 4. Discuss the different types of operators in Python and provide examples of how they are used.
#     - Arithmetic Operators
#         - Addition(+)
#         -Subtraction(-)
#         -Multiplication(*)
#         -Division(/)
#         -Modulus(%)
#         -Exponentiation(**)
#
#     - Comparison Operators
#         -Equal to (==)
#         -Not equal to (!=)
#         -Greater than (>)
#         -Less than (<)
#         -Greater than or equal to (>=)
#         -Less than or equal to (<=)
#
#     - Logical Operators
#        -Logical AND (and)
#        -Logical OR (or)
#        -Logical NOT (not)
#
#     - Bitwise Operators
#        -Bitwise AND (&)
#        -Bitwise OR (|)
#        -Bitwise XOR (^)
#        -Bitwise NOT (~)
#        -Bitwise Left Shift (<<)
#        -Bitwise Right Shift (>>)
#
#     - Assignment Operators
#        - Assign (=)
#        -Add and assign (+=)
#        -Subtract and assign (-=)
#        -Multiply and assign (*=)
#        -Divide and assign (/=)
#        -Modulus and assign (%=)
#        -Floor divide and assign (//=)
#        -Exponentiate and assign (**=)
#        -Bitwise AND and assign (&=)
#        -Bitwise OR and assign (|=)
#        -Bitwise XOR and assign (^=)
#        -Bitwise left shift and assign (<<=)
#        -Bitwise right shift and assign (>>=)
#
#     - Membership Operators
#        - In (in)
#        -Not in (not in)
#
#     - Identity Operators
#        -Is (is)
#        -Is not (is not)
#
#     - Example -
#           a = 10
#           b = 3
#
#           print(a + b)
#           print(a == b)
#           print(a += 2)
#
#           x = True
#           y = False
#           print(x and y)
#           print(a & b)
#
#           fruits = ["apple", "banana", "cherry"]
#           print("apple" in fruits)
#           print("grape" not in fruits)
#
#           x = [1, 2, 3]
#           y = x
#           z = [1, 2, 3]
#
#           print(x is y)
#           print(x is z)
#           print(x is not z)
#
#
#
# 5.  Explain the concept of type casting in Python with examples.
#       - Type casting in Python refers to converting a value from one data type to another. It allows you to use values in different formats for various operations.
#
#       - types
#         1. Explicit - You use Python’s built-in functions to convert types
#         2. Implicit - Python automatically converts one data type to another during operations, where no loss of data will occur.
#
#         - x = "10"
#           y = int(x)
#           print(y + 5)
#           answer will be 15.
#
# 6.  How do conditional statements work in Python? Illustrate with examples.
#       - Conditional statements in Python are used to execute code only when a certain condition is true. They allow your program to make decisions based on input, values, or logical conditions.
#       - Types of Conditional Statements in Python
#             -if statement
#             -if-else statement
#             -if-elif-else ladder
#             -Nested if statements
#       - example - num = 5
#                   if num % 2 == 0:
#                       print("Even number")
#                   else:
#                       print("Odd number")
#
#
# 7.  Describe the different types of loops in Python and their use cases with examples.
#       - for Loop - When you want to iterate over a sequence (like list, tuple, string, or range) a fixed number of times.
#         example - for i in range(1, 6):
#                   print(i)
#
#       - while Loop - When you want to repeat a block of code until a condition becomes False (number of iterations may be unknown beforehand).
#         example - count = 1
#                   while count <= 5:
#                       print("Count is", count)
#                       count += 1
